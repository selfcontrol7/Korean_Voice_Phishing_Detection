# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 5)

# %%
import matplotlib.pyplot as plt

# Model names
models = ['1D CNN', 'LSTM', 'BiLSTM', 'CNN-BiLSTM', 'Attention CNN-BiLSTM']

# Precision values
precision = [98.35, 97.30, 84.12, 98.99, 99.32]

# Recall values
recall = [98.29, 97.27, 84.64, 98.98, 99.32]

# Accuracy values
accuracy = [98.29, 97.27, 84.64, 98.98, 99.32]

# Plotting
plt.figure(figsize=(10, 7))
plt.plot(models, precision, marker='o', label='Precision')
plt.plot(models, recall, marker='o', label='Recall')
plt.plot(models, accuracy, marker='o', label='Accuracy')
plt.ylabel('Percentage')
plt.xlabel('Models')
plt.title('Performance of Different Models')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Model names
models = ['1D CNN', 'LSTM', 'BiLSTM', 'CNN-BiLSTM', 'Attention CNN-BiLSTM']

# Precision values
precision = [98.35, 97.30, 84.12, 98.99, 99.32]

# Recall values
recall = [98.29, 97.27, 84.64, 98.98, 99.32]

# Accuracy values
accuracy = [98.29, 97.27, 84.64, 98.98, 99.32]

# The x position of bars
barWidth = 0.25
r1 = np.arange(len(precision))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

# Create precision bars
plt.bar(r1, precision, width = barWidth, color = 'blue', edgecolor = 'grey', label='Precision')

# Create recall bars
plt.bar(r2, recall, width = barWidth, color = 'cyan', edgecolor = 'grey', label='Recall')

# Create accuracy bars
plt.bar(r3, accuracy, width = barWidth, color = 'orange', edgecolor = 'grey', label='Accuracy')

# Adding xticks
plt.xlabel('Models', fontweight='bold', fontsize = 15)
plt.ylabel('Percentage', fontweight='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(precision))], models)

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Model names
models = ['1D CNN', 'LSTM', 'BiLSTM', 'CNN-BiLSTM', 'Attention CNN-BiLSTM']

# Precision values
precision = [98.35, 97.30, 84.12, 98.99, 99.32]

# Recall values
recall = [98.29, 97.27, 84.64, 98.98, 99.32]

# Accuracy values
accuracy = [98.29, 97.27, 84.64, 98.98, 99.32]

# The x position of bars
barWidth = 0.25
r1 = np.arange(len(precision))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

# Create precision bars
plt.bar(r1, precision, width = barWidth, color = 'blue', edgecolor = 'grey', label='Precision')

# Create recall bars
plt.bar(r2, recall, width = barWidth, color = 'cyan', edgecolor = 'grey', label='Recall')

# Create accuracy bars
plt.bar(r3, accuracy, width = barWidth, color = 'orange', edgecolor = 'grey', label='Accuracy')

# Adding xticks
plt.xlabel('Models', fontweight='bold', fontsize = 15)
plt.ylabel('Percentage', fontweight='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(precision))], models)

# Adding scores on top of each bar
for i in range(len(r1)):
    plt.text(x = r1[i]-0.1 , y = precision[i]+0.1, s = f"{precision[i]}%", size = 10)
    plt.text(x = r2[i]-0.1 , y = recall[i]+0.1, s = f"{recall[i]}%", size = 10)
    plt.text(x = r3[i]-0.1 , y = accuracy[i]+0.1, s = f"{accuracy[i]}%", size = 10)

plt.legend()
plt.show()

# %%
# Load Matplotlib and data wrangling libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from time import time
from timeit import default_timer as timer
from datetime import timedelta, datetime

# Use Seaborn's context settings to make fonts larger.
import seaborn as sns
sns.set_context('talk')

labels = ['1D CNN', 'LSTM', 'BiLSTM', 'CNN-BiLSTM', 'Attention CNN-BiLSTM']
precision = [0.9835, 0.9730, 0.8412, 0.9899, 0.9932]
recall = [0.9829, 0.9727, 0.8464, 0.9898, 0.9932]
f1 = [0.9831, 0.9722, 0.8432, 0.9897, 0.9931]

# Create a grouped bar chart, with job as the x-axis
# and gender as the variable we're grouping on so there
# are two bars per job.
fig, ax = plt.subplots(figsize=(20, 8))

# Our x-axis. We basically just want a list
# of numbers from zero with a value for each
# of our jobs.
x = np.arange(len(labels))

# Define bar width. We need this to offset the second bar.
bar_width = 0.25

b1 = ax.bar(x - bar_width, precision, width=bar_width, label='Precision')
# Same thing, but offset the x.
b2 = ax.bar(x, recall, width=bar_width, label='Recall')
b3 = ax.bar(x + bar_width, f1, width=bar_width, label='F1')

# Fix the x-axes.
ax.set_xticks(x)
ax.set_xticklabels(labels)

# Add legend.
ax.legend(loc='lower center')


# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_facecolor('white')

# Add axis and chart labels.
ax.set_xlabel('Models', labelpad=15)
ax.set_ylabel('Score(%)', labelpad=15)
ax.set_title('Evaluation Metric Scores grouped by Model', pad=15)


# For each bar in the chart, add a text label.
for bar in ax.patches:
  # The text annotation for each bar should be its height.
  bar_value = bar.get_height()
  # Format the text with commas to separate thousands. You can do
  # any type of formatting here though.
  text = f'{bar_value:,}'
  # This will give the middle of each bar on the x-axis.
  text_x = bar.get_x() + bar.get_width() / 2
  # get_y() is where the bar starts so we add the height to it.
  text_y = bar.get_y() + bar_value
  # If we want the text to be the same color as the bar, we can
  # get the color like so:
  bar_color = bar.get_facecolor()
  # If you want a consistent color, you can just set it as a constant, e.g. #222222
  ax.text(text_x, text_y, text, ha='center', va='bottom', color=bar_color,
          size=15)
  
# fig.tight_layout()

plt.savefig('Evaluation Metric Scores grouped by Model_'+ datetime.now().strftime("%Y%m%d_%H-%M-%S") + '.png', dpi=600, format='png', bbox_inches='tight')
plt.savefig('Evaluation Metric Scores grouped by Model_'+ datetime.now().strftime("%Y%m%d_%H-%M-%S") + '.pdf', dpi=600, format='pdf', bbox_inches='tight')

plt.show()
plt.close()

# %%
# # Load Matplotlib and data wrangling libraries.
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# from datetime import datetime

# # Use Seaborn's context settings to make fonts larger.
# import seaborn as sns
# sns.set_context('talk')

# def save_figure(fig, ax, filename):
#     ax.set_title(filename, pad=15)
#     fig.tight_layout()
#     plt.savefig(filename + '_' + datetime.now().strftime("%Y%m%d_%H-%M-%S") + '.png', dpi=600, format='png', bbox_inches='tight')
#     plt.savefig(filename + '_' + datetime.now().strftime("%Y%m%d_%H-%M-%S") + '.pdf', dpi=600, format='pdf', bbox_inches='tight')

# labels = ['1D CNN', 'LSTM', 'BiLSTM', 'CNN-BiLSTM', 'Attention CNN-BiLSTM']
# precision = [0.9835, 0.9730, 0.8412, 0.9899, 0.9932]
# recall = [0.9829, 0.9727, 0.8464, 0.9898, 0.9932]
# f1 = [0.9831, 0.9722, 0.8432, 0.9897, 0.9931]

# fig, ax = plt.subplots(figsize=(20, 8))

# x = np.arange(len(labels))
# bar_width = 0.25

# b1 = ax.bar(x - bar_width, precision, width=bar_width, label='Precision')
# b2 = ax.bar(x, recall, width=bar_width, label='Recall')
# b3 = ax.bar(x + bar_width, f1, width=bar_width, label='F1')

# ax.set_xticks(x)
# ax.set_xticklabels(labels, rotation = 90, va="top", position=(0,-0.28))
# ax.legend(loc='lower center')

# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# ax.spines['left'].set_visible(False)
# ax.spines['bottom'].set_color('#DDDDDD')
# ax.tick_params(bottom=False, left=False)
# ax.set_axisbelow(True)
# ax.yaxis.grid(True, color='#EEEEEE')
# ax.xaxis.grid(False)
# ax.set_facecolor('white')

# ax.set_xlabel('Models', labelpad=15)
# ax.set_ylabel('Score(%)', labelpad=15)

# for bar in ax.patches:
#   bar_value = bar.get_height()
#   text = f'{bar_value:.4f}'
#   text_x = bar.get_x() + bar.get_width() / 2
#   text_y = bar.get_y() + bar_value
#   bar_color = bar.get_facecolor()
#   ax.text(text_x, text_y, text, ha='center', va='bottom', color=bar_color, size=12)

# # save_figure(fig, ax, 'Evaluation Metric Scores grouped by Model')
# plt.show()
# plt.close()

# %% [markdown]
# # Recall and Precision only

# %%
# Load Matplotlib and data wrangling libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from time import time
from timeit import default_timer as timer
from datetime import timedelta, datetime

# Use Seaborn's context settings to make fonts larger.
import seaborn as sns
sns.set_context('talk')

labels = ['1D CNN', 'LSTM', 'BiLSTM', 'CNN-BiLSTM', 'Attention CNN-BiLSTM']
precision = [0.9835, 0.9730, 0.8412, 0.9899, 0.9932]
recall = [0.9829, 0.9727, 0.8464, 0.9898, 0.9932]

# Create a grouped bar chart, with job as the x-axis
# and gender as the variable we're grouping on so there
# are two bars per job.
fig, ax = plt.subplots(figsize=(20, 8))

# Our x-axis. We basically just want a list
# of numbers from zero with a value for each
# of our jobs.
x = np.arange(len(labels))

# Define bar width. We need this to offset the second bar.
bar_width = 0.25

b1 = ax.bar(x - bar_width, precision, width=bar_width, label='Precision')
# Same thing, but offset the x.
b2 = ax.bar(x, recall, width=bar_width, label='Recall')

# Fix the x-axes.
ax.set_xticks(x)
ax.set_xticklabels(labels)

# Add legend.
ax.legend(loc='lower center')


# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_facecolor('white')

# Add axis and chart labels.
ax.set_xlabel('Models', labelpad=15)
ax.set_ylabel('Score(%)', labelpad=15)
ax.set_title('Evaluation Metric Scores grouped by Model', pad=15)


# For each bar in the chart, add a text label.
for bar in ax.patches:
  # The text annotation for each bar should be its height.
  bar_value = bar.get_height()
  # Format the text with commas to separate thousands. You can do
  # any type of formatting here though.
  text = f'{bar_value:,}'
  # This will give the middle of each bar on the x-axis.
  text_x = bar.get_x() + bar.get_width() / 2
  # get_y() is where the bar starts so we add the height to it.
  text_y = bar.get_y() + bar_value
  # If we want the text to be the same color as the bar, we can
  # get the color like so:
  bar_color = bar.get_facecolor()
  # If you want a consistent color, you can just set it as a constant, e.g. #222222
  ax.text(text_x, text_y, text, ha='center', va='bottom', color=bar_color,
          size=15)
  
# fig.tight_layout()

plt.savefig('Evaluation Metric Scores grouped by Model_'+ datetime.now().strftime("%Y%m%d_%H-%M-%S") + '.png', dpi=600, format='png', bbox_inches='tight')
plt.savefig('Evaluation Metric Scores grouped by Model_'+ datetime.now().strftime("%Y%m%d_%H-%M-%S") + '.pdf', dpi=600, format='pdf', bbox_inches='tight')

plt.show()
plt.close()

# %%
# Load Matplotlib and data wrangling libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from time import time
from timeit import default_timer as timer
from datetime import timedelta, datetime

# Use Seaborn's context settings to make fonts larger.
import seaborn as sns
sns.set_context('talk')

labels = ['1D CNN', 'LSTM', 'BiLSTM', '1D CNN-BiLSTM', 'Attention 1D CNN-BiLSTM']
precision = [0.9835, 0.9730, 0.8412, 0.9899, 0.9932]
recall = [0.9829, 0.9727, 0.8464, 0.9898, 0.9932]

# Create a grouped bar chart, with job as the x-axis
# and gender as the variable we're grouping on so there
# are two bars per job.
# fig, ax = plt.subplots(figsize=(20, 8), layout='constrained')
fig, ax = plt.subplots(figsize=(13, 8), layout='constrained')

# Our x-axis. We basically just want a list
# of numbers from zero with a value for each
# of our jobs.
x = np.arange(len(labels))

# Define bar width. We need this to offset the second bar.
bar_width = 0.35

b1 = ax.bar(x - bar_width, precision, width=bar_width, label='Precision', color='black', align='edge')
# Same thing, but offset the x.
b2 = ax.bar(x, recall, width=bar_width, label='Recall', color='red',align='edge')

# Fix the x-axes.
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=7,fontsize=20)
# ax.set_xticklabels(labels,rotation=45, fontsize=9)


# Add legend.
# ax.legend(loc='lower center')
ax.legend(loc='upper left', ncols=2)
ax.set_ylim(0, 1.1)

# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
# ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=True, left=True)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_facecolor('white')

# Add axis and chart labels.
# ax.set_xlabel('Models', labelpad=15)
ax.set_ylabel('Precision and Recall')
# ax.set_title('Comparative Precision and Recall Metrics for Baseline Models', pad=15)

for bars in ax.containers:  
    ax.bar_label(bars, label_type='center', color="white", rotation=90,fontsize=25,weight='bold')
    # ax.bar_label(bars, label_type='edge')
    

# # For each bar in the chart, add a text label.
# for bar in ax.patches:
#   # The text annotation for each bar should be its height.
#   bar_value = bar.get_height()
#   # Format the text with commas to separate thousands. You can do
#   # any type of formatting here though.
#   text = f'{bar_value:,}'
#   # This will give the middle of each bar on the x-axis.
#   text_x = bar.get_x() + bar.get_width() / 2
#   # get_y() is where the bar starts so we add the height to it.
#   text_y = bar.get_y() + bar_value
#   # If we want the text to be the same color as the bar, we can
#   # get the color like so:
#   bar_color = bar.get_facecolor()
#   # ax.bar_label(p, label_type='center')
#   # If you want a consistent color, you can just set it as a constant, e.g. #222222
#   ax.text(text_x, text_y, text, ha='center', va='bottom', color=bar_color, size=16)

# plt.savefig('pre_rec_'+ datetime.now().strftime("%Y%m%d_%H-%M-%S") + '.png', dpi=600, format='png', bbox_inches='tight')
plt.savefig('pre_rec_13.8_inside.pdf', dpi=800, format='pdf', bbox_inches='tight')

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44540\1005751342.py in <module>
#      42 # Add legend.
#      43 # ax.legend(loc='lower center')
# ---> 44 ax.legend(loc='upper left', ncols=2)
#      45 ax.set_ylim(0, 1.1)
#      46
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     303         if len(extra_args):
#     304             raise TypeError('legend only accepts two non-keyword arguments')
# --> 305         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     306         self.legend_._remove_method = self._remove_legend
#     307         return self.legend_
#
# TypeError: __init__() got an unexpected keyword argument 'ncols'

# %% [markdown]
# # F1 only

# %%
# import matplotlib.pyplot as plt

# labels = ['1D CNN', 'LSTM', 'BiLSTM', 'CNN-BiLSTM', 'Attention CNN-BiLSTM']
# f1 = [0.9831, 0.9722, 0.8432, 0.9897, 0.9931]
# bar_labels = labels

# # fig, ax = plt.subplots()
# fig, ax = plt.subplots(figsize=(10, 6), layout='constrained')

# ax.bar(labels, f1, label=bar_labels)

# ax.set_ylabel('fruit supply')
# ax.set_title('Fruit supply by kind and color')
# ax.legend(title='Fruit color')

# plt.show()

# %%
# Load Matplotlib and data wrangling libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from time import time
from timeit import default_timer as timer
from datetime import timedelta, datetime

# Use Seaborn's context settings to make fonts larger.
import seaborn as sns
sns.set_context('talk')

labels = ['1D CNN', 'LSTM', 'BiLSTM', '1D CNN-BiLSTM', 'Attention 1D CNN-BiLSTM']
f1 = [0.9831, 0.9722, 0.8432, 0.9897, 0.9931]

# Create a grouped bar chart, with job as the x-axis
# and gender as the variable we're grouping on so there
# are two bars per job.
# fig, ax = plt.subplots(figsize=(20, 8), layout='constrained')
fig, ax = plt.subplots(figsize=(13, 8), layout='constrained')

# Our x-axis. We basically just want a list
# of numbers from zero with a value for each
# of our jobs.
x = np.arange(len(labels))

# Define bar width. We need this to offset the second bar.
bar_width = 0.35

ax.bar(labels, f1, label='F1 Score')
# ax.bar(labels, f1, label='F1',hatch='..', color='red'))
# b1 = ax.bar(x - bar_width, precision, width=bar_width, label='Precision', color='black', align='edge')
# Same thing, but offset the x.
# b2 = ax.bar(x, recall, width=bar_width, label='Recall', color='red',align='edge')

# Fix the x-axes.
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=7,fontsize=20)
# ax.set_xticklabels(labels,rotation=45, fontsize=9)


# Add legend.
# ax.legend(loc='lower center')
ax.legend(loc='upper left', ncols=1)
ax.set_ylim(0, 1.1)

# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
# ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=True, left=True)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_facecolor('white')

# Add axis and chart labels.
# ax.set_xlabel('Models', labelpad=15)
ax.set_ylabel('F1 Score')
# ax.set_title('Comparative Precision and Recall Metrics for Baseline Models', pad=15)

for bars in ax.containers:  
    ax.bar_label(bars, label_type='center', color="white", rotation=90,fontsize=25,weight='bold')
    

# For each bar in the chart, add a text label.
# for bar in ax.patches:
#   # The text annotation for each bar should be its height.
#   bar_value = bar.get_height()
#   # Format the text with commas to separate thousands. You can do
#   # any type of formatting here though.
#   text = f'{bar_value:,}'
#   # This will give the middle of each bar on the x-axis.
#   text_x = bar.get_x() + bar.get_width() / 2
#   # get_y() is where the bar starts so we add the height to it.
#   text_y = bar.get_y() + bar_value
#   # If we want the text to be the same color as the bar, we can
#   # get the color like so:
#   bar_color = bar.get_facecolor()
#   # ax.bar_label(p, label_type='center')
#   # If you want a consistent color, you can just set it as a constant, e.g. #222222
#   ax.text(text_x, text_y, text, ha='center', va='bottom', color=bar_color, size=19)

# plt.savefig('pre_rec_'+ datetime.now().strftime("%Y%m%d_%H-%M-%S") + '.png', dpi=600, format='png', bbox_inches='tight')
plt.savefig('f1_13.8_inside_.pdf', dpi=800, format='pdf', bbox_inches='tight')

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44540\2246294325.py in <module>
#      43 # Add legend.
#      44 # ax.legend(loc='lower center')
# ---> 45 ax.legend(loc='upper left', ncols=1)
#      46 ax.set_ylim(0, 1.1)
#      47
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     303         if len(extra_args):
#     304             raise TypeError('legend only accepts two non-keyword arguments')
# --> 305         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     306         self.legend_._remove_method = self._remove_legend
#     307         return self.legend_
#
# TypeError: __init__() got an unexpected keyword argument 'ncols'

# %%
import matplotlib.pyplot as plt

# Model names
models = ['1D CNN', 'LSTM', 'BiLSTM', 'CNN-BiLSTM', 'Attention CNN-BiLSTM']

# Precision values
precision = [98.35, 97.30, 84.12, 98.99, 99.32]

# Recall values
recall = [98.29, 97.27, 84.64, 98.98, 99.32]

# Plotting
plt.figure(figsize=(10, 7))
plt.plot(models, precision, marker='o', label='Precision')
plt.plot(models, recall, marker='o', label='Recall')
plt.ylabel('Percentage')
plt.xlabel('Models')
plt.title('Performance of Different Models')
plt.legend()
plt.show()

# %%
animal_names = ['Lion', 'Gazelle', 'Cheetah']
mph_speed = [50, 60, 75]

fig, ax = plt.subplots()
bar_container = ax.bar(animal_names, mph_speed)
ax.set(ylabel='speed in MPH', title='Running speeds', ylim=(0, 80))
ax.bar_label(
    bar_container, fmt=lambda x: '{:.1f} km/h'.format(x * 1.61)
)
# Out:
# [Text(0, 0, '80.5 km/h'), Text(0, 0, '96.6 km/h'), Text(0, 0, '120.8 km/h')]

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

# fig, ax = plt.subplots(layout='constrained')
fig, ax = plt.subplots(figsize=(10, 8),layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()
