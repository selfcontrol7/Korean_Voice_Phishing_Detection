# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# data1 = pd.read_csv('performances_shallow_algorithm_lab.csv')
# data1.head()

plt.style.use('ggplot')
fig = plt.figure(figsize=(9,6))

N = 5

x = ['F1_score', 'Precision', 'Recall', 'Accuracy', 'Running time'] 

RF = [0.9816, 1, 0.9639, 0.9836, 2.9083]
XGB = [0.9722, 1, 0.9459, 0.9754, 1.4653]
LBG = [0.9909, 1, 0.9818, 0.9918, 1.2764]
CatBoost = [0.9769, 1, 0.9549, 0.9795, 10.1996]
SVC = [1, 1, 1, 1, 4.0595]
RNN = [0.8739, 0.8800, 0.8743, 0.8743, 7894.8924]
GRU = [0.9535, 0.9552, 0.9536, 0.9536, 260.1022]
BiLSTM = [0.9699, 0.9701, 0.9699, 0.9699, 1314.2276]




ind = np.arange(N) 
width = 0.12       
plt.bar(ind, RF, width, label='Random Forest Classifier')
plt.bar(ind + width, XGB, width, label='XGB Classifier')
plt.bar(ind + width + width, LBG, width, label='LGBM Classifier')
plt.bar(ind + width + width + width, CatBoost, width, label='Cat Boost Classifier')
plt.bar(ind + width + width + width + width, SVC, width, label='Linear SVC')
# plt.bar(ind + width + width + width + width + width, RNN, width, label='RNN')
# plt.bar(ind + width + width + width + width + width + width, GRU, width, label='GRU')
# plt.bar(ind + width + width + width + width + width + width + width, BiLSTM, width, label='BiLSTM')


plt.ylabel('MACHINE LEARNING CLASSIFIER')
plt.title('EVALUTION METRICS')

plt.xticks((ind + width + width ) , ('F1_score', 'Precision', 'Recall', 'Accuracy', 'Running time'))
plt.legend(loc='upper center')
plt.show()

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize=(9,6))

N = 4

x = ['F1_score', 'Precision', 'Recall', 'Accuracy'] 

RF = [0.981651, 1, 0.963964, 0.983607]
XGB = [0.972222, 1, 0.945946, 0.975410]
LBG = [0.990909, 1, 0.981882, 0.991803]
CatBoost = [0.976959, 1, 0.954955, 0.979508]
SVC = [1, 1, 1, 1]



ind = np.arange(N) 
width = 0.12       
plt.bar(ind, RF, width, label='Random Forest Classifier')
plt.bar(ind + width, XGB, width, label='XGB Classifier')
plt.bar(ind + width + width, LBG, width, label='LGBM Classifier')
plt.bar(ind + width + width + width, CatBoost, width, label='Cat Boost Classifier')
plt.bar(ind + width + width + width + width, SVC, width, label='Linear SVC')


plt.ylabel('MACHINE LEARNING CLASSIFIER')
plt.title('EVALUTION METRICS')

plt.xticks((ind + width + width ) , ('F1_score', 'Precision', 'Recall', 'Accuracy'))
plt.legend(loc='lower center')
plt.show()

# %%
#################################################################

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
models = ['RF', 'XGBoost', 'LGBM', 'Cat Boost ', 'LinearSVC', 'RNN', 'GRU', 'BiLSTM']
f1 = [1,
      0.9504,
      0.9943,
      0.9799,
      1,
      0.8739,
      0.9535,
      0.9699
      ]
rects1 = ax.bar(models,f1, color='tab:blue')
plt.title('ML MODELS F1-SCORES ON TEST SET')
plt.xlabel('ML Models')
plt.ylabel('F1-score values')
# for i, v in enumerate(f1):
#     # ax.text(v + 3, i + .25, str(v), color='blue', fontweight='bold')
#     plt.text(v, i, " "+str(f1), color='blue', ha='center', va='bottom', fontweight='bold')

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)

plt.show()

# %%
################################################################

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
models = ['RF', 'XGBoost', 'LGBM', 'Cat Boost ', 'LinearSVC', 'RNN', 'GRU', 'BiLSTM']
accuracy = [1,
            0.9535,
            0.9945,
            0.9808,
            1,
            0.8743,
            0.9536,
            0.9699
            ]
rects2 = ax.bar(models,accuracy, color='tab:green')

plt.title('ML MODELS ACCURACY ON TEST SET')
plt.xlabel('ML Models')
plt.ylabel('Accuracy values')  

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects2)

plt.show()

# %% [markdown]
# # Source
# https://matplotlib.org/3.3.3/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['RF', 'XGBoost', 'LGBM', 'Cat Boost ', 'LinearSVC', 'RNN', 'GRU', 'BiLSTM']
men_means = [1,
            0.9535,
            0.9945,
            0.9808,
            1,
            0.8743,
            0.9536,
            0.9699]

x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax = fig.add_axes([0,0,1,1])
rects1 = ax.bar(x, men_means, label='Men')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
# ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)

# fig.tight_layout()

plt.show()

# %% [markdown]
# # Running Time

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['XGBoost', 'LGBM', 'BiLSTM', 'CatBoost ', 'GRU', 'RNN', 'KoBERT']
men_means = [0.4695,
            1.2836,
            1314.2276,
            7.5432,
            260.1022,
            7894.8924,
            224.9638]

x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax = fig.add_axes([0,0,1,1])
rects1 = ax.bar(x, men_means, label='Algorithms', color='cyan')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Time in second')
ax.set_xlabel('ML and DL Algorithms')
ax.set_title('Modeling training time in second')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)
ax.set_facecolor("white")
# ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)

# fig.tight_layout()

plt.show()

# %% [markdown]
# # Precision

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['XGBoost', 'LGBM', 'BiLSTM', 'CatBoost ', 'GRU', 'RNN', 'KoBERT']
men_means = [
             98.19,
             99.43,
             97.01,
             99.41,
             95.52,
             88.00,
             100
             ]

x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax = fig.add_axes([0,0,1,1])
rects1 = ax.bar(x, men_means, label='Algorithms', color='lightcoral')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('ML and DL Algorithms')
ax.set_title('Precision')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)
# ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)

# fig.tight_layout()

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['XGBoost', 'LGBM', 'BiLSTM', 'CatBoost ', 'GRU', 'RNN', "KoBERT"]
men_means = [
             92.09,
             99.43,
             96.99,
             96.61,
             95.36,
             87.43,
             99.14
             ]

x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax = fig.add_axes([0,0,1,1])
rects1 = ax.bar(x, men_means, label='Algorithms', color='sandybrown')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Score')
ax.set_xlabel('ML and DL Algorithms')
ax.set_title('Recall')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)
# ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)

# fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
y=['one', 'two', 'three', 'four', 'five']

# getting values against each value of y
x=[5,24,35,67,12]
plt.barh(y, x)

# setting label of y-axis
plt.ylabel("pen sold")

# setting label of x-axis
plt.xlabel("price")
plt.title("Horizontal bar graph")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5, 6, 7]
y = [160, 167, 17, 130, 120, 40, 105, 70]
fig, ax = plt.subplots()
width = 0.75
ind = np.arange(len(y))

ax.barh(ind, y, width, color = "green")

for i, v in enumerate(y):
   ax.text(v + 3, i + .25, str(v),
         color = 'blue', fontweight = 'bold')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['XGBoost', 'LGBM', 'BiLSTM', 'CatBoost ', 'GRU', 'RNN', 'KoBERT']
men_means = [0.4695,
            1.2836,
            1314.2276,
            7.5432,
            260.1022,
            7894.8924,
            201.2960]

fig, ax = plt.subplots()
width = 0.75
ind = np.arange(len(men_means))

ax.barh(labels, men_means, width, color = "cyan")
ax.set_xlabel('Time in second')
ax.set_ylabel('ML and DL Algorithms')
ax.set_title('Modeling training time in second')

for i, v in enumerate(men_means):
   ax.text(v + 3, i + .20, str(v),
         color = 'black')
plt.show()
